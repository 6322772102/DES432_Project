# %%
#import necesary libraries
import pandas as pd
import numpy as np
# %matplotlib inline
# Out:
# Bad pipe message: %s [b'8\xac7}\xe57\x1c\x07\xb0\x82\x1b<\xeb\x03Q\xa3+\x9d \xc6\x19u\x81H\xf8\xb2\xee\xa1\xedul\r\xc1\x9b\xf0\x15\xfc\x9b\xb4!\xd8\x17\xcaP0\x0c\x1c8\x0c\xf5\xf4\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00', b'\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \x10\xd2\x92Z\x083e^*OR\xd69\x88\x8eI\x1b?\x00\x1awU\xaa\x9fWZ\xcb\xf1\xc1<\xb4']
# ...
